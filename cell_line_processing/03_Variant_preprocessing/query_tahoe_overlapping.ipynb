# %% [markdown]
# This file is the tahoe equivalent of the lincs processing notebook "merge_variants_into_lincs.ipynb". It uses cell lines existing in both tahoe and lincs.

# %%
import pandas as pd

# %%
tahoe_path = '../data/final_tahoe_overlapping_lincs.parquet'
tahoe = pd.read_parquet(tahoe_path, engine='pyarrow')

# %%
tahoe
# Out:
#      index                  cl_sm_dose  cell_line          drug  dose  \
# 0        0     CVCL_0023_APTO-253_0.05  CVCL_0023      APTO-253  0.05
# 1        1     CVCL_0023_AZD-7648_0.05  CVCL_0023      AZD-7648  0.05
# 2        2     CVCL_0023_AZD-8055_0.05  CVCL_0023      AZD-8055  0.05
# 3        3      CVCL_0023_AZD1390_0.05  CVCL_0023       AZD1390  0.05
# 4        4     CVCL_0023_Afatinib_0.05  CVCL_0023      Afatinib  0.05
# ..     ...                         ...        ...           ...   ...
# 913   7693  CVCL_1478_Methotrexate_0.5  CVCL_1478  Methotrexate  0.50
# 914   7695  CVCL_1478_Panobinostat_0.5  CVCL_1478  Panobinostat  0.50
# 915   7697     CVCL_1478_Sunitinib_0.5  CVCL_1478     Sunitinib  0.50
# 916   7698    CVCL_1478_Trametinib_0.5  CVCL_1478    Trametinib  0.50
# 917   7700    CVCL_1478_Vandetanib_0.5  CVCL_1478    Vandetanib  0.50
#
#     pubchem_cid       cell_line_drug  responses  \
# 0      11960271   CVCL_0023_11960271   0.989992
# 1     135151360  CVCL_0023_135151360   0.991688
# 2      25262965   CVCL_0023_25262965   0.689011
# 3     126689157  CVCL_0023_126689157   0.999031
# 4      10184653   CVCL_0023_10184653   0.912780
# ..          ...                  ...        ...
# 913      126941     CVCL_1478_126941   0.308163
# 914     6918837    CVCL_1478_6918837   0.133373
# 915     5329102    CVCL_1478_5329102   0.999995
# 916    11707110   CVCL_1478_11707110   0.493729
# 917     3081361    CVCL_1478_3081361   0.905767
#
#                                                 smiles  fps_0  ...      9985  \
# 0    CC1=C(C2=C(N1)C=CC(=C2)F)C3=NC4=C5C=CC=NC5=C6C...      0  ...  1.842929
# 1    CC1=CC2=NC=NN2C=C1NC3=NC=C4C(=N3)N(C(=O)N4C)C5...      0  ...  2.075660
# 2    CC1COCCN1C2=NC(=NC3=C2C=CC(=N3)C4=CC(=C(C=C4)O...      0  ...  1.366750
# 3    CC(C)N1C2=C(C=NC3=CC(=C(C=C32)C4=CN=C(C=C4)OCC...      0  ...  1.823357
# 4    CN(C)CC=CC(=O)NC1=C(C=C2C(=C1)C(=NC=N2)NC3=CC(...      0  ...  1.965340
# ..                                                 ...    ...  ...       ...
# 913  CN(CC1=CN=C2C(=N1)C(=NC(=N2)N)N)C3=CC=C(C=C3)C...      0  ...  2.735610
# 914    CC1=C(C2=CC=CC=C2N1)CCNCC3=CC=C(C=C3)C=CC(=O)NO      0  ...  0.892772
# 915  CCN(CC)CCNC(=O)C1=C(NC(=C1C)C=C2C3=C(C=CC(=C3)...      0  ...  1.493024
# 916  CC1=C2C(=C(N(C1=O)C)NC3=C(C=C(C=C3)I)F)C(=O)N(...      0  ...  1.904285
# 917  CN1CCC(CC1)COC2=C(C=C3C(=C2)N=CN=C3NC4=C(C=C(C...      0  ...  0.893898
#
#          9987      9988      9989        999      9990      9991      9992  \
# 0    0.366734 -0.335411  0.782379  -0.359100 -0.234669  2.092593  0.000000
# 1    0.152147  0.160935  0.444318  -0.384877 -0.837646  2.344321  0.000000
# 2    0.400315  0.087598  0.663222   0.103934 -0.031691  2.111688  0.000000
# 3   -0.357533 -0.097746  0.487961  -1.207489 -0.640630  2.030661  0.000000
# 4   -0.081255 -0.490730  0.402371  -0.153901 -0.327424  2.319682  0.000000
# ..        ...       ...       ...        ...       ...       ...       ...
# 913  1.073833  0.780114  2.272395   9.924588  1.177306 -1.630280  0.000000
# 914  0.285116 -0.338122 -2.081486   8.706774  2.293502 -2.431107  0.159213
# 915  1.080804  0.569372  2.476869   9.739894  0.029816 -2.853831  0.000000
# 916  0.399307  0.659193  1.318983  10.313108  0.685268 -2.115262  0.000000
# 917  1.103211  1.512507  1.494593   9.744642  0.777044 -1.918199  0.000000
#
#          9993      9997
# 0   -0.832242  1.058628
# 1   -0.937542  0.649613
# 2   -1.267154  0.513679
# 3   -1.128126  0.567049
# 4   -1.040558  0.416956
# ..        ...       ...
# 913  1.659517  1.655166
# 914  1.648496  1.531785
# 915  1.380650  1.280002
# 916  1.827661  1.221012
# 917  1.316742  0.552843
#
# [918 rows x 14385 columns]

# %%
tahoe['cell_line'].unique().size
# Out:
# 8

# %%
variant_path = '../data/mutations_cellosaurus_full.csv'
variants = pd.read_csv(variant_path)
variants = variants[variants['cellosaurus_ids.accession'].isin(tahoe['cell_line'])]
variants_subset = variants[[
    'cellosaurus_ids.accession',
    'HugoSymbol',
    'DNAChange',
    'VariantType'
]]
# Out:
# C:\Users\Leo\AppData\Local\Temp\ipykernel_80292\2546803751.py:2: DtypeWarning: Columns (23,51,57,58,59,60,62,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   variants = pd.read_csv(variant_path)

# %%
variants_subset
# Out:
#        cellosaurus_ids.accession HugoSymbol                    DNAChange  \
# 15806                  CVCL_0023       ENO1  ENST00000234590.10:c.795T>G
# 15807                  CVCL_0023     NMNAT1   ENST00000377205.6:c.660C>A
# 15808                  CVCL_0023     CELA2B    ENST00000375910.8:c.40G>T
# 15809                  CVCL_0023      USP48  ENST00000308271.14:c.362C>A
# 15810                  CVCL_0023     ADGRB2  ENST00000373658.8:c.1864C>A
# ...                          ...        ...                          ...
# 440472                 CVCL_1478      ZFP92  ENST00000338647.7:c.1100A>T
# 440473                 CVCL_1478      IRAK1  ENST00000369980.8:c.1177G>A
# 440474                 CVCL_1478      CTAG2     ENST00000369585.4:c.3G>T
# 440475                 CVCL_1478         F8  ENST00000360256.9:c.2783T>A
# 440476                 CVCL_1478      SPRY3   ENST00000695325.1:c.400G>C
#
#        VariantType
# 15806          SNV
# 15807          SNV
# 15808          SNV
# 15809          SNV
# 15810          SNV
# ...            ...
# 440472         SNV
# 440473         SNV
# 440474         SNV
# 440475         SNV
# 440476         SNV
#
# [7704 rows x 4 columns]

# %%
# check how many unique mutations there are
all_mutations = list(set(variants_subset['DNAChange']))
print(f"number of unique mutations: {len(all_mutations)}")

# create a dict
# keys are the cell lines
# values are lists that contain all mutations in that cell line
variant_by_cell_line = {}
for cell_line, group in variants_subset[['cellosaurus_ids.accession', 'DNAChange']].groupby('cellosaurus_ids.accession'):
    # Convert group to list of dictionaries, excluding the grouping column
    variant_by_cell_line[cell_line] = group['DNAChange'].tolist()
# Out:
# number of unique mutations: 7685

# %%
# join the mutation data to tahoe
tahoe['mutations'] = tahoe['cell_line'].map(variant_by_cell_line)
tahoe['mutations'] = tahoe['mutations'].apply(lambda x: x if isinstance(x, list) else [])

# %%
print("Setup Done and starting creation of matrix", flush = True)
# we are creating an empty data frame
# rows = cell lines
# columns = mutations
# we use bools because its the data type needing the least memory
mutation_presence = pd.DataFrame(0, index=range(tahoe.shape[0]), columns=all_mutations, dtype=bool)

# we convert it to a numpy array and 
mutation_array = mutation_presence.values
# create a dict that maps column names to integer position
mutation_cols = {col: i for i, col in enumerate(mutation_presence.columns)}

# now we iterate trough the mutations
for idx, muts in enumerate(tahoe['mutations']):
    if (idx % 2000 == 0):
        print(f"Iteration {idx} ....", flush = True)
    if isinstance(muts, list) and len(muts) > 0:
        # get the column indices for all present mutations, so we can set them at the same time
        # this is a huge speed improvement over basic iterating
        col_indices = [mutation_cols[mut] for mut in muts if mut in mutation_cols]
        mutation_array[idx, col_indices] = True

# Convert back to DataFrame for concatenating
mutation_presence = pd.DataFrame(mutation_array, 
                                index=mutation_presence.index, 
                                columns=mutation_presence.columns,
                                dtype=bool)
                                
print("Concatenating ...", flush = True)
tahoe_with_mutations = pd.concat([tahoe, mutation_presence], axis=1)

print("Write to file ...", flush = True)
tahoe_with_mutations.to_parquet(path='data/tahoe_overlapping_variant_matrix.parquet', engine='pyarrow')
# Out:
# Setup Done and starting creation of matrix
# Iteration 0 ....
# Concatenating ...
# Write to file ...
# c:\Users\Leo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\io\parquet.py:189: UserWarning: The DataFrame has column names of mixed type. They will be converted to strings and not roundtrip correctly.
#   table = self.api.Table.from_pandas(df, **from_pandas_kwargs)

# %% [markdown]
# # Aggregating mutations by Gene

# %%
# this is just here because during EDA I was looking at a lot of different things
variants_subset = variants[[
    'cellosaurus_ids.accession',
    'HugoSymbol'
    ]]

# check how many unique genes there are
all_genes = list(set(variants_subset['HugoSymbol']))
print(f"number of unique genes: {len(all_genes)}")

# create a dict
# keys are the cell lines
# values are lists that contain all mutations in that cell line
grouped = variants_subset.groupby(['cellosaurus_ids.accession', 'HugoSymbol']).size().reset_index(name='count')
result = grouped.groupby('cellosaurus_ids.accession').apply(
    lambda x: dict(zip(x['HugoSymbol'], x['count']))
).to_dict()

print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # this is just here because during EDA I was looking at a lot of different things
# ----> 2 variants_subset = variants[[
#       3     'cellosaurus_ids.accession',
#       4     'HugoSymbol'
#       5     ]]
#       7 # check how many unique genes there are
#       8 all_genes = list(set(variants_subset['HugoSymbol']))
#
# NameError: name 'variants' is not defined

# %%
mut_df = pd.DataFrame.from_dict(result, orient='index').fillna(0).astype(int)
mut_df['cellosaurus_ids.accession'] = mut_df.index

# %%
mut_df
# Out:
#            ABCB1  ABRAXAS2  ABTB3  ACADL  ADAM11  ADGRB2  AGTR1  ANKHD1  \
# CVCL_0023      1         1      1      1       1       1      1       1
# CVCL_1478      0         1      0      0       0       0      0       0
# CVCL_0028      0         0      0      0       1       1      0       0
# CVCL_0293      0         0      0      0       0       0      0       0
# CVCL_0179      0         0      0      0       0       0      0       0
# CVCL_0320      0         0      0      0       0       0      0       0
# CVCL_0359      0         0      0      0       0       0      0       0
# CVCL_0332      0         0      0      0       0       0      0       0
#
#            ANKIB1  AP2B1  ...  ZNF559  ZNF653  ZNF672  ZNF710  ZNF784  \
# CVCL_0023       1      1  ...       0       0       0       0       0
# CVCL_1478       0      0  ...       1       1       1       1       1
# CVCL_0028       0      0  ...       0       0       0       0       0
# CVCL_0293       0      0  ...       0       0       0       0       0
# CVCL_0179       0      0  ...       0       0       0       0       0
# CVCL_0320       0      0  ...       0       0       0       0       0
# CVCL_0359       0      0  ...       0       0       0       0       0
# CVCL_0332       0      0  ...       0       0       0       0       0
#
#            ZNF804B  ZP4  ZPLD1  ZRANB2  cellosaurus_ids.accession
# CVCL_0023        0    0      0       0                  CVCL_0023
# CVCL_1478        2    1      1       1                  CVCL_1478
# CVCL_0028        0    0      0       0                  CVCL_0028
# CVCL_0293        0    0      0       0                  CVCL_0293
# CVCL_0179        0    0      0       0                  CVCL_0179
# CVCL_0320        0    0      0       0                  CVCL_0320
# CVCL_0359        0    0      0       0                  CVCL_0359
# CVCL_0332        0    0      0       0                  CVCL_0332
#
# [8 rows x 5481 columns]

# %%
tahoe_gene_level_muts = pd.merge(tahoe, mut_df, left_on='cell_line', right_on='cellosaurus_ids.accession', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tahoe_gene_level_muts = pd.merge(tahoe, mut_df, left_on='cell_line', right_on='cellosaurus_ids.accession', how='Cell')
#
# File c:\Users\Leo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:183, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168 else:
#     169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#    (...)
#     181         validate=validate,
#     182     )
# --> 183     return op.get_result(copy=copy)
#
# File c:\Users\Leo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:883, in _MergeOperation.get_result(self, copy)
#     880 if self.indicator:
#     881     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 883 join_index, left_indexer, right_indexer = self._get_join_info()
#     885 result = self._reindex_and_concat(
#     886     join_index, left_indexer, right_indexer, copy=copy
#     887 )
#     888 result = result.__finalize__(self, method=self._merge_type)
#
# File c:\Users\Leo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:1133, in _MergeOperation._get_join_info(self)
#    1129     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1130         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1131     )
#    1132 else:
# -> 1133     (left_indexer, right_indexer) = self._get_join_indexers()
#    1135     if self.right_index:
#    1136         if len(self.left) > 0:
#
# File c:\Users\Leo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:1105, in _MergeOperation._get_join_indexers(self)
#    1103 def _get_join_indexers(self) -> tuple[npt.NDArray[np.intp], npt.NDArray[np.intp]]:
#    1104     """return the join indexers"""
# -> 1105     return get_join_indexers(
#    1106         self.left_join_keys, self.right_join_keys, sort=self.sort, how=self.how
#    1107     )
#
# File c:\Users\Leo\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:1718, in get_join_indexers(left_keys, right_keys, sort, how)
#    1716 if how in ("left", "right"):
#    1717     kwargs["sort"] = sort
# -> 1718 join_func = {
#    1719     "inner": libjoin.inner_join,
#    1720     "left": libjoin.left_outer_join,
#    1721     "right": lambda x, y, count, **kwargs: libjoin.left_outer_join(
#    1722         y, x, count, **kwargs
#    1723     )[::-1],
#    1724     "outer": libjoin.full_outer_join,
#    1725 }[how]
#    1727 # error: Cannot call function of unknown type
#    1728 return join_func(lkey, rkey, count, **kwargs)
#
# KeyError: 'Cell'

# %%
tahoe_gene_level_muts.to_parquet(path='data/tahoe_overlapping_gene_level_matrix.parquet', engine='pyarrow')
